# %% [markdown]
# ### 导入dfply，其中已包含diamonds数据集

# %%
from dfply import *

# %% [markdown]
# ### 导入seaborn模块，取别名sns

# %%
import seaborn as sns

# %% [markdown]
# diamonds是一个pandas数据框（dataframe），支持一切pandas数据框操作：

# %%
type(diamonds)
# Out:
# pandas.core.frame.DataFrame

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
diamonds.tail(10)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %% [markdown]
# ### 用.describe()取得各列的描述统计：

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# ### 也可以使用dfply以更统一的方式操作数据框：

# %%
diamonds >> head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds >> tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamonds >> sample(100) #取样
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 10022   0.31      Ideal     I     SI1   60.9   57.0    414  4.36  4.41  2.67
# 45739   0.53      Ideal     E     VS1   60.9   57.0   1700  5.19  5.25  3.18
# 21109   1.21    Premium     F     VS1   60.1   58.0   9279  6.89  6.98  4.17
# 33180   0.41  Very Good     E     SI2   63.2   58.0    818  4.72  4.68  2.97
# 47389   0.54      Ideal     E     VS2   61.4   57.0   1847  5.25  5.21  3.21
# 37637   0.40    Premium     D     SI1   61.7   58.0    990  4.74  4.70  2.91
# 34287   0.26      Ideal     H    VVS1   61.2   56.0    468  4.11  4.16  2.53
# 47617   0.55      Ideal     F     VS1   61.6   57.0   1881  5.23  5.29  3.24
# 35070   0.32  Very Good     F    VVS1   61.5   57.0    886  4.38  4.41  2.70
# 29442   0.38  Very Good     D     SI1   61.3   57.0    701  4.67  4.70  2.87
# 16451   1.20      Ideal     H     SI1   62.2   58.0   6569  6.81  6.77  4.22
# 52245   0.70      Ideal     I    VVS2   62.4   53.6   2487  5.68  5.72  3.55
# 3570    0.70       Good     E     VS1   58.4   61.0   3419  5.85  5.89  3.43
# 11784   1.13  Very Good     E     SI1   60.8   58.0   5086  6.71  6.77  4.10
# 8664    0.90    Premium     G     SI1   62.6   57.0   4455  6.16  6.11  3.84
# 2289    0.90  Very Good     H     SI2   61.1   63.0   3160  6.12  6.19  3.76
# 28638   0.33  Very Good     G     SI2   59.4   59.0    434  4.50  4.52  2.68
# 45644   0.25      Ideal     G    VVS2   62.1   56.0    525  4.02  4.05  2.50
# 52155   0.73  Very Good     F     SI1   59.7   60.0   2473  5.83  5.90  3.50
# 28259   0.33    Premium     G     VS1   61.4   59.0    666  4.43  4.49  2.74
# 43046   0.54    Premium     E     SI1   62.2   61.0   1375  5.24  5.15  3.23
# 25898   1.24      Ideal     F    VVS1   61.2   55.0  15026  6.94  6.98  4.26
# 4649    0.90       Good     H     VS1   64.0   59.0   3669  6.05  6.01  3.86
# 51309   0.31       Good     E     SI1   63.4   55.0    544  4.32  4.35  2.75
# 49789   0.77  Very Good     I     VS2   62.4   63.0   2162  5.84  5.80  3.63
# 13605   1.17       Good     D     SI2   60.4   65.0   5567  6.81  6.77  4.10
# 4210    0.87      Ideal     E     SI2   60.4   58.0   3566  6.19  6.23  3.75
# 45972   0.30       Good     E     SI1   63.2   57.0    526  4.25  4.30  2.70
#
# [100 rows x 10 columns]

# %% [markdown]
# ### 取得每种cut的数量：

# %%
diamonds >> group_by(X.cut) >> summarise(num = X.cut.count())
# Out:
#          cut    num
# 0       Fair   1610
# 1       Good   4906
# 2      Ideal  21551
# 3    Premium  13791
# 4  Very Good  12082

# %% [markdown]
# ### 取得每种cut的数量：

# %%
diamonds >> group_by(X.color) >> summarise(num = X.color.count())
# Out:
#   color    num
# 0     D   6775
# 1     E   9797
# 2     F   9542
# 3     G  11292
# 4     H   8304
# 5     I   5422
# 6     J   2808

# %% [markdown]
# ### 用seaborn作散点图

# %%
# %matplotlib inline
sns.scatterplot(data=diamonds>>sample(1000),x="carat",y="price")

# %% [markdown]
# ### 根据cut分为不同颜色

# %%
# %matplotlib inline
sns.scatterplot(data=diamonds>>sample(1000),x="carat",y="price",hue="cut")

# %% [markdown]
# ### 根据color分为不同大小或形状

# %%
# %matplotlib notebook
sns.scatterplot(data=diamonds >> sample(1000),x="carat",y="price",hue="cut",size="color")
# Out:
# <img src="data:image/png;base64,..." width="638">

# %%
# %matplotlib notebook
sns.scatterplot(data=diamonds >> sample(1000),x="carat",y="price",hue="cut",style="color")
# Out:
# <img src="data:image/png;base64,..." width="572">

# %% [markdown]
# ### 用直方图表现价格分布

# %%
# %matplotlib inline
sns.distplot(diamonds.price)
# Out:
# /home/zh/.local/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 将不同color下的价格分布表现在同一张图的不同子图中：

# %%
g = sns.FacetGrid(diamonds,col="color",margin_titles=True)
g.map(sns.distplot,"price")

# %% [markdown]
# ### 用boxenplot表现不同color下的分布：

# %%
sns.boxenplot(data=diamonds,x="color",y="price")

# %% [markdown]
# ### 用violinplot表现不同color下的分布：

# %%
sns.violinplot(data=diamonds,x="color",y="price")

# %% [markdown]
# ### 获取不同clarity下的价格均值：

# %%
mean_price = diamonds >> group_by(X.clarity) >> summarise(mprice= mean(X.price))

# %% [markdown]
# ### 用条形图表现不同clarity下的价格均值：

# %%
sns.barplot(data=mean_price,x="clarity",y="mprice")

# %% [markdown]
# ### 用pairplot表现price、depth、table的相互关系：

# %%
sns.pairplot(data=diamonds>> sample(500)>>select(X.cut,X.price,X.depth,X.table),hue="cut")

# %% [markdown]
# ## 进一步参考：
# - seaborn gallery: https://seaborn.pydata.org/examples/index.html
# - dfply: https://github.com/kieferk/dfply
